# %% [markdown]
# # Pandas: grouping

# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("data/vehicles.csv")

# %%
cars.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# How many Car models?

# %%
print(cars["Model"].nunique())
# Out:
# 3608

# %% [markdown]
# group by the data by the Make  using count function

# %%
cars.groupby("Make").count()
# Out:
#                              Model  Year  Engine Displacement  Cylinders  \
# Make
# AM General                       4     4                    4          4
# ASC Incorporated                 1     1                    1          1
# Acura                          302   302                  302        302
# Alfa Romeo                      41    41                   41         41
# American Motors Corporation     22    22                   22         22
# ...                            ...   ...                  ...        ...
# Volkswagen                    1047  1047                 1047       1047
# Volvo                          717   717                  717        717
# Wallace Environmental           32    32                   32         32
# Yugo                             8     8                    8          8
# smart                           20    20                   20         20
#
#                              Transmission  Drivetrain  Vehicle Class  \
# Make
# AM General                              4           4              4
# ASC Incorporated                        1           1              1
# Acura                                 302         302            302
# Alfa Romeo                             41          41             41
# American Motors Corporation            22          22             22
# ...                                   ...         ...            ...
# Volkswagen                           1047        1047           1047
# Volvo                                 717         717            717
# Wallace Environmental                  32          32             32
# Yugo                                    8           8              8
# smart                                  20          20             20
#
#                              Fuel Type  Fuel Barrels/Year  City MPG  \
# Make
# AM General                           4                  4         4
# ASC Incorporated                     1                  1         1
# Acura                              302                302       302
# Alfa Romeo                          41                 41        41
# American Motors Corporation         22                 22        22
# ...                                ...                ...       ...
# Volkswagen                        1047               1047      1047
# Volvo                              717                717       717
# Wallace Environmental               32                 32        32
# Yugo                                 8                  8         8
# smart                               20                 20        20
#
#                              Highway MPG  Combined MPG  \
# Make
# AM General                             4             4
# ASC Incorporated                       1             1
# Acura                                302           302
# Alfa Romeo                            41            41
# American Motors Corporation           22            22
# ...                                  ...           ...
# Volkswagen                          1047          1047
# Volvo                                717           717
# Wallace Environmental                 32            32
# Yugo                                   8             8
# smart                                 20            20
#
#                              CO2 Emission Grams/Mile  Fuel Cost/Year
# Make
# AM General                                         4               4
# ASC Incorporated                                   1               1
# Acura                                            302             302
# Alfa Romeo                                        41              41
# American Motors Corporation                       22              22
# ...                                              ...             ...
# Volkswagen                                      1047            1047
# Volvo                                            717             717
# Wallace Environmental                             32              32
# Yugo                                               8               8
# smart                                             20              20
#
# [127 rows x 14 columns]

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Converting Gallons to Liters
#
# 1 Gallon = 3.78541 Liters

# %% [markdown]
# What brand has the most cars?

# %%
makers = cars['Make'].value_counts()
makers
# Chevrolet is the brand with most cars, 3643 in total.
# Out:
# Chevrolet                             3643
# Ford                                  2946
# Dodge                                 2360
# GMC                                   2347
# Toyota                                1836
#                                       ...
# Excalibur Autos                          1
# S and S Coach Company  E.p. Dutton       1
# Environmental Rsch and Devp Corp         1
# E. P. Dutton, Inc.                       1
# Lambda Control Systems                   1
# Name: Make, Length: 127, dtype: int64

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand

# %%
cars["CO2 Emission Grams/Km"] = cars["CO2 Emission Grams/Mile"] * 0.621371
cars_emission = cars.groupby("Make")[["CO2 Emission Grams/Km"]].mean()
cars_emission
# Out:
#                              CO2 Emission Grams/Km
# Make
# AM General                              379.880283
# ASC Incorporated                        345.132755
# Acura                                   262.582266
# Alfa Romeo                              288.286390
# American Motors Corporation             314.263866
# ...                                            ...
# Volkswagen                              244.038316
# Volvo                                   270.795815
# Wallace Environmental                   408.855922
# Yugo                                    221.250488
# smart                                   153.497623
#
# [127 rows x 1 columns]

# %% [markdown]
# <b>show the average CO2_Emission_Grams/Km  by Brand ... sorted

# %%
cars_emission.sort_values(by='CO2 Emission Grams/Km', ascending=True)
# Out:
#                                     CO2 Emission Grams/Km
# Make
# Fisker                                         105.011699
# smart                                          153.497623
# Fiat                                           189.310965
# Daihatsu                                       192.741865
# MINI                                           194.934560
# ...                                                   ...
# Laforza Automobile Inc                         502.011280
# Bugatti                                        542.495719
# Superior Coaches Div E.p. Dutton               552.212408
# S and S Coach Company  E.p. Dutton             552.212408
# Vector                                         651.917426
#
# [127 rows x 1 columns]

# %% [markdown]
# # (Optional)

# %% [markdown]
# Use `pd.cut` or `pd.qcut` to create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
cars['Year'].describe()
# Out:
# count    35952.00000
# mean      2000.71640
# std         10.08529
# min       1984.00000
# 25%       1991.00000
# 50%       2001.00000
# 75%       2010.00000
# max       2017.00000
# Name: Year, dtype: float64

# %%
labels = ["80's", "90's", "2000's", "2010's"]

cars['Decade'] = pd.qcut(cars['Year'], q=4, labels=labels)

cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
#        CO2 Emission Grams/Km  Decade
# 0                 324.830828    80's
# 1                 424.778775    80's
# 2                 345.132755    80's
# 3                 424.778775    80's
# 4                 345.132755    80's
# ...                      ...     ...
# 35947             151.614524  2010's
# 35948             150.993153  2010's
# 35949             151.614524  2010's
# 35950             152.857266  2010's
# 35951             158.449605  2010's
#
# [35952 rows x 17 columns]

# %% [markdown]
# ### Did cars consume more gas in the eighties?

# %% [markdown]
# show the average City_Km/Liter by year_range

# %%
cars["City_Km/Liter"] = cars["City MPG"] * 0.425144

print(cars.groupby(["Decade"])['City_Km/Liter'].mean())

#Cars from the 80's, 90's and 2000's seem to consume almost the same amount of gas, on average...
# ...while cars from the 2010's seem to be more efficient.
# Out:
# Decade
# 80's      7.326122
# 90's      7.210345
# 2000's    7.208461
# 2010's    8.394453
# Name: City_Km/Liter, dtype: float64

# %% [markdown]
# Which brands are more environment friendly?

# %%
cars.groupby("Make")["CO2 Emission Grams/Km"].mean().sort_values()

#Since their cars emit less CO2 per km, on average, the most environment friendly brands are Fisker, Smart and Fiat.
# Out:
# Make
# Fisker                                105.011699
# smart                                 153.497623
# Fiat                                  189.310965
# Daihatsu                              192.741865
# MINI                                  194.934560
#                                          ...
# Laforza Automobile Inc                502.011280
# Bugatti                               542.495719
# Superior Coaches Div E.p. Dutton      552.212408
# S and S Coach Company  E.p. Dutton    552.212408
# Vector                                651.917426
# Name: CO2 Emission Grams/Km, Length: 127, dtype: float64

# %% [markdown]
# Does the drivetrain affect fuel consumption?

# %%
cars.groupby(["Drivetrain"])["Fuel Barrels/Year"].mean().sort_values(ascending=False)

# Cars with 2-Wheel Drive seem to consume most amount of fuel, while the 2-Wheel Drive, Front ones seem to consume the least.
# Out:
# Drivetrain
# 2-Wheel Drive                 21.069467
# Part-time 4-Wheel Drive       20.628218
# 4-Wheel or All-Wheel Drive    20.484720
# Rear-Wheel Drive              19.587486
# 4-Wheel Drive                 17.942952
# All-Wheel Drive               16.349672
# Front-Wheel Drive             14.266654
# 2-Wheel Drive, Front          11.771786
# Name: Fuel Barrels/Year, dtype: float64

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
cars["Automatic?"] = cars["Transmission"]

cars.loc[cars['Automatic?'].str.contains("Auto", "auto"), "Automatic?"] = "Automatic"
cars.loc[cars['Automatic?'].str.contains("Manual", "manual"), "Automatic?"] = "Manual"

cars.groupby(["Automatic?"])["Fuel Barrels/Year"].mean()

# Yes, automatic cars seem to consume more fuel, on average.
# Out:
# Automatic?
# Automatic    18.043152
# Manual       16.704904
# Name: Fuel Barrels/Year, dtype: float64

# %% [markdown]
# Use `groupby` and `agg` with different aggregation measures for different columns:

# %% [markdown]
# aggregate with average City_Km/Liter and the count of the Trans

# %%
cars.groupby(["Transmission"]).agg({"Transmission":['count'], "City_Km/Liter": ['mean']})
# Out:
#                                  Transmission City_Km/Liter
#                                         count          mean
# Transmission
# Auto (AV)                                   2     14.880040
# Auto (AV-S6)                                1      9.353168
# Auto (AV-S8)                                1      8.502880
# Auto(A1)                                    1     17.430904
# Auto(AM-S6)                                92     10.337469
# Auto(AM-S7)                               256      7.544645
# Auto(AM-S8)                                 6     10.061741
# Auto(AM-S9)                                 1      8.928024
# Auto(AM5)                                  12     14.313181
# Auto(AM6)                                 110     10.164807
# Auto(AM7)                                 157      6.907913
# Auto(AM8)                                   5      9.523226
# Auto(AV-S6)                               145     11.030288
# Auto(AV-S7)                                63     11.883787
# Auto(AV-S8)                                26      9.712905
# Auto(L3)                                    2      5.952016
# Auto(L4)                                    2      5.739444
# Automatic (A1)                              3     14.454896
# Automatic (A6)                              4      5.952016
# Automatic (AM5)                             2     14.029752
# Automatic (AM6)                             1      5.526872
# Automatic (AV)                              4      9.246882
# Automatic (AV-S6)                           9     10.061741
# Automatic (S4)                            229      7.684153
# Automatic (S5)                            822      7.264687
# Automatic (S6)                           2631      7.796084
# Automatic (S7)                            261      7.144374
# Automatic (S8)                            960      7.843907
# Automatic (S9)                             26      8.470177
# Automatic (variable gear ratios)          675     11.674769
# Automatic 3-spd                          2597      7.418656
# Automatic 4-spd                         10585      6.778607
# Automatic 5-spd                          2171      6.566526
# Automatic 6-spd                          1432      7.108693
# Automatic 6spd                              1      8.928024
# Automatic 7-spd                           662      7.277540
# Automatic 8-spd                           243      7.047243
# Automatic 9-spd                            90      8.535947
# Manual 3-spd                               74      6.049684
# Manual 4-spd                             1306      7.172759
# Manual 5 spd                                1      5.952016
# Manual 5-spd                             7787      8.180760
# Manual 6-spd                             2423      7.782785
# Manual 7-spd                               68      7.746374
# Manual(M7)                                  3      5.952016

# %% [markdown]
# aggregate with average City_Km/Liter and the minimum of the Trans

# %%
cars.groupby(["Transmission"]).agg({"Transmission":['min'], "City_Km/Liter": ['mean']})
# Out:
#                                                       Transmission  \
#                                                                min
# Transmission
# Auto (AV)                                                Auto (AV)
# Auto (AV-S6)                                          Auto (AV-S6)
# Auto (AV-S8)                                          Auto (AV-S8)
# Auto(A1)                                                  Auto(A1)
# Auto(AM-S6)                                            Auto(AM-S6)
# Auto(AM-S7)                                            Auto(AM-S7)
# Auto(AM-S8)                                            Auto(AM-S8)
# Auto(AM-S9)                                            Auto(AM-S9)
# Auto(AM5)                                                Auto(AM5)
# Auto(AM6)                                                Auto(AM6)
# Auto(AM7)                                                Auto(AM7)
# Auto(AM8)                                                Auto(AM8)
# Auto(AV-S6)                                            Auto(AV-S6)
# Auto(AV-S7)                                            Auto(AV-S7)
# Auto(AV-S8)                                            Auto(AV-S8)
# Auto(L3)                                                  Auto(L3)
# Auto(L4)                                                  Auto(L4)
# Automatic (A1)                                      Automatic (A1)
# Automatic (A6)                                      Automatic (A6)
# Automatic (AM5)                                    Automatic (AM5)
# Automatic (AM6)                                    Automatic (AM6)
# Automatic (AV)                                      Automatic (AV)
# Automatic (AV-S6)                                Automatic (AV-S6)
# Automatic (S4)                                      Automatic (S4)
# Automatic (S5)                                      Automatic (S5)
# Automatic (S6)                                      Automatic (S6)
# Automatic (S7)                                      Automatic (S7)
# Automatic (S8)                                      Automatic (S8)
# Automatic (S9)                                      Automatic (S9)
# Automatic (variable gear ratios)  Automatic (variable gear ratios)
# Automatic 3-spd                                    Automatic 3-spd
# Automatic 4-spd                                    Automatic 4-spd
# Automatic 5-spd                                    Automatic 5-spd
# Automatic 6-spd                                    Automatic 6-spd
# Automatic 6spd                                      Automatic 6spd
# Automatic 7-spd                                    Automatic 7-spd
# Automatic 8-spd                                    Automatic 8-spd
# Automatic 9-spd                                    Automatic 9-spd
# Manual 3-spd                                          Manual 3-spd
# Manual 4-spd                                          Manual 4-spd
# Manual 5 spd                                          Manual 5 spd
# Manual 5-spd                                          Manual 5-spd
# Manual 6-spd                                          Manual 6-spd
# Manual 7-spd                                          Manual 7-spd
# Manual(M7)                                              Manual(M7)
#
#                                  City_Km/Liter
#                                           mean
# Transmission
# Auto (AV)                            14.880040
# Auto (AV-S6)                          9.353168
# Auto (AV-S8)                          8.502880
# Auto(A1)                             17.430904
# Auto(AM-S6)                          10.337469
# Auto(AM-S7)                           7.544645
# Auto(AM-S8)                          10.061741
# Auto(AM-S9)                           8.928024
# Auto(AM5)                            14.313181
# Auto(AM6)                            10.164807
# Auto(AM7)                             6.907913
# Auto(AM8)                             9.523226
# Auto(AV-S6)                          11.030288
# Auto(AV-S7)                          11.883787
# Auto(AV-S8)                           9.712905
# Auto(L3)                              5.952016
# Auto(L4)                              5.739444
# Automatic (A1)                       14.454896
# Automatic (A6)                        5.952016
# Automatic (AM5)                      14.029752
# Automatic (AM6)                       5.526872
# Automatic (AV)                        9.246882
# Automatic (AV-S6)                    10.061741
# Automatic (S4)                        7.684153
# Automatic (S5)                        7.264687
# Automatic (S6)                        7.796084
# Automatic (S7)                        7.144374
# Automatic (S8)                        7.843907
# Automatic (S9)                        8.470177
# Automatic (variable gear ratios)     11.674769
# Automatic 3-spd                       7.418656
# Automatic 4-spd                       6.778607
# Automatic 5-spd                       6.566526
# Automatic 6-spd                       7.108693
# Automatic 6spd                        8.928024
# Automatic 7-spd                       7.277540
# Automatic 8-spd                       7.047243
# Automatic 9-spd                       8.535947
# Manual 3-spd                          6.049684
# Manual 4-spd                          7.172759
# Manual 5 spd                          5.952016
# Manual 5-spd                          8.180760
# Manual 6-spd                          7.782785
# Manual 7-spd                          7.746374
# Manual(M7)                            5.952016
